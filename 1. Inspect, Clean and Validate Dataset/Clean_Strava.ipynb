# %%
import pandas as pd

# %%
strava_df = pd.read_csv("../DataInput/Strava/activities.csv")
strava_df.head()
# Out:
#    Activity ID          Activity Date Activity Name Activity Type  \
# 0   3560035534   3 Jun 2020, 19:41:27   Evening Run           Run
# 1   3580028155   7 Jun 2020, 19:21:30   Evening Run           Run
# 2   3620485461  15 Jun 2020, 19:40:57   Evening Run           Run
# 3   3625765530  16 Jun 2020, 19:48:38   Evening Run           Run
# 4   3651044244  21 Jun 2020, 19:18:14   Evening Run           Run
#
#   Activity Description  Elapsed Time  Distance  Max Heart Rate  \
# 0                  NaN          3434      5.42             NaN
# 1                  NaN          3192      5.30             NaN
# 2                  NaN          2854      5.23             NaN
# 3                  NaN          2851      5.29             NaN
# 4                  NaN          3792      6.57             NaN
#
#    Relative Effort  Commute  ... Intensity Average Grade Adjusted Pace  \
# 0              NaN    False  ...       NaN                         NaN
# 1              NaN    False  ...       NaN                         NaN
# 2              NaN    False  ...       NaN                         NaN
# 3              NaN    False  ...       NaN                         NaN
# 4              NaN    False  ...       NaN                         NaN
#
#   Timer Time  Total Cycles  Recovery  With Pet  Competition  Long Run  \
# 0        NaN           NaN       NaN       NaN          NaN       NaN
# 1        NaN           NaN       NaN       NaN          NaN       NaN
# 2        NaN           NaN       NaN       NaN          NaN       NaN
# 3        NaN           NaN       NaN       NaN          NaN       NaN
# 4        NaN           NaN       NaN       NaN          NaN       NaN
#
#    For a Cause  Media
# 0          NaN    NaN
# 1          NaN    NaN
# 2          NaN    NaN
# 3          NaN    NaN
# 4          NaN    NaN
#
# [5 rows x 99 columns]

# %% [markdown]
# subset of the columns

# %%
strava_df = strava_df[["Activity Date", "Activity Name", "Activity Type", "Distance", "Calories"]]

# %%
strava_df
# Out:
#              Activity Date              Activity Name    Activity Type  \
# 0     3 Jun 2020, 19:41:27                Evening Run              Run
# 1     7 Jun 2020, 19:21:30                Evening Run              Run
# 2    15 Jun 2020, 19:40:57                Evening Run              Run
# 3    16 Jun 2020, 19:48:38                Evening Run              Run
# 4    21 Jun 2020, 19:18:14                Evening Run              Run
# ..                     ...                        ...              ...
# 919  14 Aug 2025, 19:22:19                Evening Run              Run
# 920  15 Aug 2025, 13:03:31            Back and biceps  Weight Training
# 921  15 Aug 2025, 18:20:14                Evening Run              Run
# 922  16 Aug 2025, 12:20:53  Afternoon Weight Training  Weight Training
# 923  17 Aug 2025, 12:48:21  Afternoon Weight Training  Weight Training
#
#      Distance  Calories
# 0        5.42       NaN
# 1        5.30       NaN
# 2        5.23       NaN
# 3        5.29       NaN
# 4        6.57       NaN
# ..        ...       ...
# 919      5.17     311.0
# 920      0.00      95.0
# 921      2.90     177.0
# 922      0.00     128.0
# 923      0.00     123.0
#
# [924 rows x 5 columns]

# %% [markdown]
# Here, calories marked as NaN are useful- they signify that an activity has occurred in that day, but the data is missing.

# %% [markdown]
# Lets adjust activity date column into dd/mm/yyyy

# %%
activity_date = strava_df["Activity Date"].apply(lambda s: " ".join(s.split(" ")[:3]))
activity_date = activity_date.apply(lambda s: s[:-1])
activity_date = pd.to_datetime(activity_date)
activity_date.head()
# Out:
# 0   2020-06-03
# 1   2020-06-07
# 2   2020-06-15
# 3   2020-06-16
# 4   2020-06-21
# Name: Activity Date, dtype: datetime64[ns]

# %%
strava_df["Activity Date"] = activity_date
strava_df
# Out:
#     Activity Date              Activity Name    Activity Type  Distance  \
# 0      2020-06-03                Evening Run              Run      5.42
# 1      2020-06-07                Evening Run              Run      5.30
# 2      2020-06-15                Evening Run              Run      5.23
# 3      2020-06-16                Evening Run              Run      5.29
# 4      2020-06-21                Evening Run              Run      6.57
# ..            ...                        ...              ...       ...
# 919    2025-08-14                Evening Run              Run      5.17
# 920    2025-08-15            Back and biceps  Weight Training      0.00
# 921    2025-08-15                Evening Run              Run      2.90
# 922    2025-08-16  Afternoon Weight Training  Weight Training      0.00
# 923    2025-08-17  Afternoon Weight Training  Weight Training      0.00
#
#      Calories
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 919     311.0
# 920      95.0
# 921     177.0
# 922     128.0
# 923     123.0
#
# [924 rows x 5 columns]

# %% [markdown]
# Dateset should be cleaned, save to file

# %%
strava_df.to_csv("./CleanedData/Cleaned_Strava.csv")
